# %%
import rebound
import numpy as np

from IPython.display import display, clear_output
import matplotlib.pyplot as plt

# %%
sim = rebound.Simulation.from_file("solar_system_outer_planets.bin")

# %%
def hill_radius(planet, sim):
    return

# %%
for planet in sim.particles[1:]:
    planet.r =

# %%
def randomize_sim(sim, max_t):
    sim.integrate(sim.t + np.random.random()*max_t + 1)
    return sim

# %%
for i in range(10**4):
    sim = randomize_sim(sim, 100)
    sim.save("solar_system_outer_planets_{:04d}.bin".format(i))

# %%
sim = rebound.Simulation.from_file("solar_system_outer_planets_5439.bin")

# %%
rebound.OrbitPlot(sim)

# %%
sim = rebound.Simulation()
sim.add(m=1.0)
sim.add(a=4.0)

# %%
for i in range(10**4):
    sim = rebound.Simulation.from_file("solar_system_outer_planets_{:04d}.bin".format(i))
    fig = rebound.OrbitPlot(sim,color=True,unitlabel="[AU]")
    display(fig)
    plt.close(fig)
    clear_output(wait=True)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/simon/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-1fd95e54eb19>", line 4, in <module>
#     display(fig)
#   File "/home/simon/.local/lib/python3.6/site-packages/IPython/core/display.py", line 304, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "/home/simon/.local/lib/python3.6/site-packages/IPython/core/formatters.py", line 180, in format
#     data = formatter(obj)
#   File "</home/simon/.local/lib/python3.6/site-packages/decorator.py:decorator-gen-9>", line 2, in __call__
#   File "/home/simon/.local/lib/python3.6/site-packages/IPython/core/formatters.py", line 224, in catch_format_error
#     r = method(self, *args, **kwargs)
# ...

# %%
for i in range(10**4):
    sim = rebound.Simulation.from_file("solar_system_outer_planets_{:04d}.bin".format(i))
    print(sim.t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-13ac7876df33> in <module>
#       1 for i in range(10**4):
# ----> 2     sim = rebound.Simulation.from_file("solar_system_outer_planets_{:04d}.bin".format(i))
#       3     print(sim.t)
#
# NameError: name 'rebound' is not defined
