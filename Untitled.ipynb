# %%
import rebound

# %%
sim = rebound.Simulation()

# %%
sim.add(m=1., x=0.4)

# %%
sim.add(a=1, m=0.01)

# %%
sim.integrate(sim.t+0.5)

# %%
print(sim.t)
sim.t=0
print(sim.t)
sim.move_to_com()
rebound.OrbitPlot(sim).show()
# Out:
# 0.5
# 0.0
